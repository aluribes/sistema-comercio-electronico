# %% [markdown]
# # Sistema de Recomendación

# %% [markdown]
# <p style="text-align: justify;">
# Se presenta un sistema de recomendación de productos basado en similitud de contenido para el dataset de productos de Amazon. Se utilizan técnicas de procesamiento de texto, codificación categórica y normalización de variables numéricas para construir un modelo eficiente que sugiera productos similares a los seleccionados por un usuario. La evaluación del sistema se realiza mediante métricas de precisión, recall y F1-score.
# </p>

# %% [markdown]
# ### ¿Qué es un sistema de recomendación?

# %% [markdown]
# Los sistemas de recomendación son herramientas fundamentales en el comercio electrónico, permitiendo personalizar la experiencia del usuario al sugerir productos que pueden ser de su interés. En este trabajo, se implementa un sistema de recomendación basado en contenido para un conjunto de datos de productos de Amazon, utilizando técnicas de minería de texto y aprendizaje automático.

# %% [markdown]
# ### Descripción del Dataset

# %% [markdown]
# El dataset utilizado proviene de Kaggle y contiene información sobre productos de Amazon, incluyendo atributos como:
#
# - **name**: El nombre del producto
# - **main_category**: La categoría principal a la que pertenece el producto
# - **sub_category**: La categoría principal a la que pertenece el producto
# - **image**: La imagen del producto
# - **link**: El enlace de referencia del producto al sitio web de Amazon
# - **ratings**: Las calificaciones otorgadas por los clientes de Amazon al producto
# - **no of ratings**: La cantidad de calificaciones otorgadas a este producto en las compras de Amazon
# - **discount_price**: Los precios con descuento del producto
# - **actual_price**: El precio de venta al público real del producto

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/work/T-shirts and Polos.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### **Importar Librerías**

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import hstack, csr_matrix

# %%
dataset = pd.read_csv("/work/T-shirts and Polos.csv")

# copia del DataFrame a trabajar
df = dataset.copy()

print(df.head(10))
# Out:
#                                                 name   main_category  \
# 0                 Allen Solly Men's Regular Fit Polo  men's clothing
# 1            Van Heusen Men's Regular Fit Polo Shirt  men's clothing
# 2  Scott International Men's Regular Fit T-Shirt ...  men's clothing
# 3  TOPLOT T-Shirt for Men||T Shirt||White T-Shirt...  men's clothing
# 4     Amazon Brand - Symbol Men's Regular Polo Shirt  men's clothing
# 5  LEOTUDE Women's Cottonblend Half Sleeve Oversi...  men's clothing
# 6                        Chromozome Men Mens Tshirts  men's clothing
# 7  London Hills Solid Men Half Sleeve Pure Cotton...  men's clothing
# 8    Amazon Brand - Symbol Men's Regular Fit T-Shirt  men's clothing
# 9                    Adidas Men's Regular Polo Shirt  men's clothing
#
#        sub_category                                              image  \
# 0  T-shirts & Polos  https://m.media-amazon.com/images/I/71eUwDk8z+...
# 1  T-shirts & Polos  https://m.media-amazon.com/images/I/71ISzvgAl2...
# 2  T-shirts & Polos  https://m.media-amazon.com/images/I/71HBNT3R66...
# 3  T-shirts & Polos  https://m.media-amazon.com/images/I/71GITfTSeR...
# 4  T-shirts & Polos  https://m.media-amazon.com/images/I/51K0XmUVDP...
# 5  T-shirts & Polos  https://m.media-amazon.com/images/I/61bzvKukDh...
# 6  T-shirts & Polos  https://m.media-amazon.com/images/I/71X7pa5hBT...
# 7  T-shirts & Polos  https://m.media-amazon.com/images/I/71tJWaahoD...
# 8  T-shirts & Polos  https://m.media-amazon.com/images/I/71xpdVWXoQ...
# 9  T-shirts & Polos  https://m.media-amazon.com/images/I/714emthUQu...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Allen-Solly-Regular-AMKP...     4.1        60,020
# 1  https://www.amazon.in/Van-Heusen-Solid-Regular...     4.0        28,727
# 2  https://www.amazon.in/Scott-International-SS20...     3.7        36,734
# 3  https://www.amazon.in/TOPLOT-T-Shirt-Regular-P...     4.5            51
# 4  https://www.amazon.in/Amazon-Brand-Symbol-Regu...     3.9        21,352
# 5  https://www.amazon.in/LEOTUDE-Oversize-Round-T...     3.6           159
# 6  https://www.amazon.in/Chromozome-Regular-T-Shi...     3.9        15,479
# 7  https://www.amazon.in/London-Hills-Solid-Sleev...     3.8           932
# 8  https://www.amazon.in/Amazon-Brand-Regular-T-S...     3.9         2,897
# 9  https://www.amazon.in/Adidas-Regular-Mens-Shir...     3.9           743
#
#   discount_price actual_price
# 0           ₹590       ₹1,099
# 1           ₹550       ₹1,099
# 2           ₹523       ₹2,397
# 3           ₹299       ₹1,999
# 4           ₹309       ₹1,099
# 5           ₹294       ₹1,099
# 6           ₹399         ₹915
# 7           ₹199       ₹1,299
# 8           ₹199         ₹699
# 9           ₹629       ₹1,799

# %% [markdown]
# ## Metodología

# %% [markdown]
# El sistema de recomendación se implementa en varias etapas:

# %% [markdown]
# ### Preprocesamiento de Datos

# %% [markdown]
# 1. **Eliminación de valores nulos**: Se eliminan registros con información incompleta para evitar sesgos en el modelo.

# %%
df = df.dropna()

# %% [markdown]
# 2. **Procesamiento de texto mediante TF-IDF**: Se aplica el algoritmo **TF-IDF (Term Frequency - Inverse Document Frequency)** para representar los nombres y categorías de los productos, destacando términos importantes en la descripción.

# %%
# 1. Procesar texto con TF-IDF
text_features = df['name'].fillna('') + " " + df['main_category'].fillna('') + " " + df['sub_category'].fillna('')
tfidf = TfidfVectorizer(stop_words='english', max_features=1000)  # Reducir a 1000 características para optimizar
tfidf_matrix = tfidf.fit_transform(text_features)

# %% [markdown]
# 3. **Codificación de variables categóricas mediante One-Hot Encoding**: Se convierten las categorías de productos en representaciones numéricas utilizando One-Hot Encoding para mejorar la representación de los datos.

# %%
# 2. Convertir categorías en One-Hot Encoding
ohe = OneHotEncoder(handle_unknown='ignore', sparse=True)  # Mantener en formato disperso
categories_matrix = ohe.fit_transform(df[['main_category', 'sub_category']])
categories_matrix
# Out:
# <12092x2 sparse matrix of type '<class 'numpy.float64'>'
# 	with 24184 stored elements in Compressed Sparse Row format>

# %%
# Limpiar valores en 'no_of_ratings'
df['no_of_ratings'] = df['no_of_ratings'].astype(str)
df['no_of_ratings'] = df['no_of_ratings'].str.replace(',', '', regex=True)
df['no_of_ratings'] = df['no_of_ratings'].str.extract('(\d+)')  # Extraer solo los números

df['actual_price'] = df['actual_price'].str.replace(',', '', regex=True).str.replace('₹', '', regex=True)
df['discount_price'] = df['discount_price'].str.replace(',', '', regex=True).str.replace('₹', '', regex=True)

# Convertir a float, reemplazando NaN con 0 si es necesario
df['no_of_ratings'] = pd.to_numeric(df['no_of_ratings'], errors='coerce').fillna(0)
df['ratings'] = pd.to_numeric(df['ratings'], errors='coerce').fillna(0)

# %% [markdown]
# 4. **Normalización de variables numéricas con MinMaxScaler**: Se normalizan las características como precios y calificaciones en un rango de [0,1] usando MinMaxScaler para evitar que variables con valores grandes dominen la similitud

# %%
# 3. Normalizar valores numéricos
numeric_features = ['ratings', 'no_of_ratings', 'actual_price']
scaler = MinMaxScaler()
numeric_matrix = scaler.fit_transform(df[numeric_features])
numeric_matrix = csr_matrix(numeric_matrix)  # Convertir en sparse matrix

# %% [markdown]
# 5. **Reducción de dimensionalidad con Truncated SVD**: Se usa Truncated SVD para reducir la dimensión de la matriz de características textuales y mejorar la eficiencia del modelo.

# %%
# 4. Reducir la Dimensión del TF-IDF
svd = TruncatedSVD(n_components=50)  # Reduce a 50 componentes
tfidf_reduced = svd.fit_transform(tfidf_matrix)
tfidf_reduced = csr_matrix(tfidf_reduced)  # Convertir a sparse matrix

# %%
# 5. Concatenar todas las representaciones en formato disperso
final_matrix = hstack([tfidf_reduced, categories_matrix, numeric_matrix])
print(final_matrix)
# Out:
#   (0, 0)	0.424120549180051
#   (0, 1)	-0.19936593020932108
#   (0, 2)	-0.02408199883183356
#   (0, 3)	-0.18038394286728443
#   (0, 4)	0.0037819459414465554
#   (0, 5)	0.016692995652933463
#   (0, 6)	0.006556311442078637
#   (0, 7)	0.027616063620166366
#   (0, 8)	-0.026019079813249493
#   (0, 9)	0.04550998480512318
#   (0, 10)	0.019271532718903403
#   (0, 11)	0.13980696196793088
#   (0, 12)	-0.03080894863769102
#   (0, 13)	0.11882654257501549
#   (0, 14)	0.06360786239383547
#   (0, 15)	-0.06455937142065363
#   (0, 16)	0.13993513324937176
#   (0, 17)	0.30625901427399316
#   (0, 18)	0.05394359857056824
#   (0, 19)	0.6624142800495754
#   (0, 20)	-0.305859447980003
#   (0, 21)	-0.07991128486998997
#   (0, 22)	0.00013404113195013626
#   (0, 23)	0.0027381496483266897
#   (0, 24)	-0.13747931304575628
#   :	:
#   (12091, 30)	0.2124760607764646
#   (12091, 31)	0.15887535507808836
#   (12091, 32)	0.03295798827909129
#   (12091, 33)	-0.009067790056766046
#   (12091, 34)	0.04197375444736147
#   (12091, 35)	0.010435817339497905
#   (12091, 36)	-0.032962810291187444
#   (12091, 37)	-0.030220769963762575
#   (12091, 38)	0.05337063093955534
#   (12091, 39)	-0.07106003612001646
#   (12091, 40)	0.007714002360502474
#   (12091, 41)	0.004032948313016819
#   (12091, 42)	-0.05968552616039066
#   (12091, 43)	0.03375084159901646
#   (12091, 44)	-0.016997394140372005
#   (12091, 45)	0.05201178759874473
#   (12091, 46)	0.045444857154341343
#   (12091, 47)	-0.07309669688257382
#   (12091, 48)	-0.02607776600693634
#   (12091, 49)	-0.0060578703038946975
#   (12091, 50)	1.0
#   (12091, 51)	1.0
#   (12091, 52)	0.78
#   (12091, 53)	0.00026658224895449777
#   (12091, 54)	0.15762426284751474

# %% [markdown]
# ## Construcción de la Matriz de Similitud

# %% [markdown]
# Se genera una representación vectorial combinando las características anteriores y se calcula la similitud coseno entre productos.

# %% [markdown]
# La función `cosine_similarity` se utiliza para medir la similitud entre vectores calculando el coseno del ángulo que forman en el espacio vectorial. Esta medida es especialmente útil en aplicaciones donde la dirección de los vectores es más relevante que su magnitud, como en sistemas de recomendación y procesamiento de lenguaje natural.
#
# ## Definición Matemática
#
# Dados dos vectores $ \mathbf{a} $ y $ \mathbf{b} $, la similitud coseno se define como:
#
# $$
# \begin{equation}
# \text{cosine\_similarity}(\mathbf{a}, \mathbf{b}) = \frac{\mathbf{a} \cdot \mathbf{b}}{\|\mathbf{a}\| \, \|\mathbf{b}\|}
# \end{equation}
# $$
#
# donde:
#
# - $ \mathbf{a} \cdot \mathbf{b} $ es el **producto escalar** de $ \mathbf{a} $ y $ \mathbf{b} $.
# - $ \|\mathbf{a}\| $ es la **norma** del vector $ \mathbf{a} $, calculada como:
#
# $$
# \begin{equation}
# \|\mathbf{a}\| = \sqrt{\sum_{i=1}^{n} a_i^2}
# \end{equation}
# $$
#
# De manera similar, la norma del vector $ \mathbf{b} $ se calcula como:
#
# $$
# \begin{equation}
# \|\mathbf{b}\| = \sqrt{\sum_{i=1}^{n} b_i^2}
# \end{equation}
# $$
#
#
# El valor resultante de la similitud coseno se encuentra en el rango \([-1, 1]\), donde:
#
# - **1** indica que los vectores son idénticos en dirección.
# - **0** indica que los vectores son ortogonales (sin correlación en la dirección).
# - **-1** indica que los vectores tienen direcciones opuestas.
#
# ## Uso en Scikit-Learn
#
# En la librería [scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html), se puede observar la documentación sobre la función `cosine_similarity`.

# %%
from scipy.sparse import csr_matrix
from sklearn.metrics.pairwise import cosine_similarity

# Convertir a formato disperso
final_matrix_sparse = csr_matrix(final_matrix)

# Calcular similitud por bloques en memoria reducida
similarity_matrix = cosine_similarity(final_matrix_sparse, dense_output=False)

# %% [markdown]
# Resultados al aplicar al aplicar `cosine_similarity` para obtener la matriz de similaridad:

# %%
print(similarity_matrix)
# Out:
# [[1.         0.80634022 0.82877353 ... 0.76835073 0.70965516 0.76031432]
#  [0.80634022 1.         0.83222845 ... 0.8456123  0.78819991 0.84106602]
#  [0.82877353 0.83222845 1.         ... 0.85579312 0.80577697 0.851106  ]
#  ...
#  [0.76835073 0.8456123  0.85579312 ... 1.         0.89473971 0.93330927]
#  [0.70965516 0.78819991 0.80577697 ... 0.89473971 1.         0.9309524 ]
#  [0.76031432 0.84106602 0.851106   ... 0.93330927 0.9309524  1.        ]]

# %% [markdown]
# <p align="center"><strong>Tabla 1:</strong> Resultados Matriz de Similaridad.</p>
#
# <p align="center"><em style="font-size: smaller;">Elaboración propia.</em></p>

# %%
product = "Allen Solly Men's Regular Fit Polo"

df[df['name'] == product ]
# Out:
#                                      name   main_category      sub_category  \
# 0      Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 18     Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 43     Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 1310   Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 1686   Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 1830   Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 1848   Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 2490   Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 4111   Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 7666   Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 8549   Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 8594   Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 9394   Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 9450   Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 13755  Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
# 14986  Allen Solly Men's Regular Fit Polo  men's clothing  T-shirts & Polos
#
#                                                    image  \
# 0      https://m.media-amazon.com/images/I/71eUwDk8z+...
# 18     https://m.media-amazon.com/images/I/81RcNGzlIh...
# 43     https://m.media-amazon.com/images/I/91tOI54L+n...
# 1310   https://m.media-amazon.com/images/I/61SFP-eFJp...
# 1686   https://m.media-amazon.com/images/I/61bJZ+ZZil...
# 1830   https://m.media-amazon.com/images/I/61f7aMUn5c...
# 1848   https://m.media-amazon.com/images/I/61SFP-eFJp...
# 2490   https://m.media-amazon.com/images/I/710Lu8wzRa...
# 4111   https://m.media-amazon.com/images/I/61qGNWBC1X...
# 7666   https://m.media-amazon.com/images/I/614ocjm7Xl...
# 8549   https://m.media-amazon.com/images/I/611QpxFohK...
# 8594   https://m.media-amazon.com/images/I/611QpxFohK...
# 9394   https://m.media-amazon.com/images/W/IMAGERENDE...
# 9450   https://m.media-amazon.com/images/I/61Lq5mMgZu...
# 13755  https://m.media-amazon.com/images/I/61Gz9FRBMJ...
# 14986  https://m.media-amazon.com/images/I/616VsOQ2kK...
#
#                                                     link  ratings  \
# 0      https://www.amazon.in/Allen-Solly-Regular-AMKP...      4.1
# 18     https://www.amazon.in/Allen-Solly-Regular-T-Sh...      4.2
# 43     https://www.amazon.in/Allen-Solly-Regular-T-Sh...      4.2
# 1310   https://www.amazon.in/Allen-Solly-Solid-Regula...      5.0
# 1686   https://www.amazon.in/Allen-Solly-Solid-Regula...      3.9
# 1830   https://www.amazon.in/Allen-Solly-Solid-Regula...      4.6
# 1848   https://www.amazon.in/Allen-Solly-Solid-Regula...      5.0
# 2490   https://www.amazon.in/Allen-Solly-Solid-Regula...      3.6
# 4111   https://www.amazon.in/Allen-Solly-Printed-Regu...      3.0
# 7666   https://www.amazon.in/Allen-Solly-Solid-Regula...      3.5
# 8549   https://www.amazon.in/Allen-Solly-Solid-Regula...      4.0
# 8594   https://www.amazon.in/Allen-Solly-Solid-Regula...      4.0
# 9394   https://www.amazon.in/Allen-Solly-Solid-Regula...      4.2
# 9450   https://www.amazon.in/Allen-Solly-Solid-Regula...      4.2
# 13755  https://www.amazon.in/Allen-Solly-Solid-Regula...      3.9
# 14986  https://www.amazon.in/Allen-Solly-Solid-Regula...      4.7
#
#        no_of_ratings discount_price actual_price
# 0              60020            590         1099
# 18              3868            579         1199
# 43              3582            689         1149
# 1310               1            689         1049
# 1686              12            839         1049
# 1830               2            828         1049
# 1848               1            689         1049
# 2490              18            799          999
# 4111               1            799          999
# 7666               9            689         1049
# 8549              25            799          999
# 8594              25            799          999
# 9394               6            933         1049
# 9450               6            933         1049
# 13755              8            629         1049
# 14986              4            799          999

# %% [markdown]
# <p align="center"><strong>Tabla 2:</strong> Top 10 de Productos.</p>
#
# <p align="center"><em style="font-size: smaller;">Elaboración propia.</em></p>

# %%
# test = df.loc[950,'name']
# test

# Print the products in the cart by their indices
cart_indices = [0]

# Display cart items
cart_items = df.iloc[cart_indices][['name', 'main_category', 'actual_price', 'ratings', 'no_of_ratings']]
cart_items
# Out:
#                                  name   main_category actual_price  ratings  \
# 0  Allen Solly Men's Regular Fit Polo  men's clothing         1099      4.1
#
#    no_of_ratings
# 0          60020

# %% [markdown]
# ## Algoritmo de Recomendación

# %% [markdown]
# Dado un conjunto de productos seleccionados, el sistema:
#
# 1. Obtiene la matriz de similitud coseno.
#
# 2. Calcula el promedio de similitud con los productos en el carrito.
#
# 3. Ordena los productos según su similitud y filtra los más relevantes.

# %%
from scipy.sparse import csr_matrix
import numpy as np

def recommend(cart_indices, df, similarity_matrix, top_n=5):
    # Convertir a matriz densa si es necesario
    if isinstance(similarity_matrix, csr_matrix):
        similarity_matrix = similarity_matrix.toarray() 

    # Obtener puntajes de similitud para cada producto en el carrito
    sim_scores = np.mean([similarity_matrix[idx] for idx in cart_indices], axis=0)

    # Enumerar y ordenar por similitud descendente
    sim_scores = list(enumerate(sim_scores))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Remover los productos que ya están en el carrito
    sim_scores = [item for item in sim_scores if item[0] not in cart_indices]
    
    # Seleccionar los top_n índices, eliminando duplicados basados en 'name'
    unique_top_indices = []
    seen_names = set()
    for idx, score in sim_scores:
        product_name = df.iloc[idx]['name']
        if product_name not in seen_names:
            unique_top_indices.append(idx)
            seen_names.add(product_name)
        if len(unique_top_indices) >= top_n:
            break

    # Retornar detalles de los productos recomendados
    return df.iloc[unique_top_indices][['name', 'main_category', 'image', 'sub_category', 'actual_price', 'ratings', 'no_of_ratings']]

# %% [markdown]
# Se ejecuta el algoritmo de recomendación utilizando el primer producto del dataset, que corresponde a `Allen Solly Men's Regular Fit Polo`. A continuación, se presentan los resultados del algoritmo, que muestra los 10 productos más similares a este primer producto.

# %%
# Prueba con los índices del carrito
recommend(cart_indices, df, similarity_matrix, top_n=10)
# Out:
#                                                     name   main_category  \
# 18                    Allen Solly Men's Regular Fit Polo  men's clothing
# 26                 Allen Solly Men's Regular Fit T-Shirt  men's clothing
# 18025           Allen Solly Men's Regular Fit Polo Shirt  men's clothing
# 14114               Allen Solly Men's Regular Polo Shirt  men's clothing
# 4613   Allen Solly Men's Regular Fit T-Shirt (ALKCVSG...  men's clothing
# 4920   Allen Solly Men's Regular Fit T-Shirt (ALKCVSG...  men's clothing
# 18275  Allen Solly Men's Regular Fit T-Shirt (ALKCVSG...  men's clothing
# 162                                 Allen Solly Men Polo  men's clothing
# 8996   Allen Solly Men's Regular Fit T-Shirt (ALKCVSG...  men's clothing
# 6287   Allen Solly Men's Regular Fit T-Shirt (ALKCVSG...  men's clothing
#
#                                                    image      sub_category  \
# 18     https://m.media-amazon.com/images/I/81RcNGzlIh...  T-shirts & Polos
# 26     https://m.media-amazon.com/images/I/71m0PW9bIM...  T-shirts & Polos
# 18025  https://m.media-amazon.com/images/I/51LmPsR0XZ...  T-shirts & Polos
# 14114  https://m.media-amazon.com/images/I/519jb9GGiQ...  T-shirts & Polos
# 4613   https://m.media-amazon.com/images/I/61KrpVDw9i...  T-shirts & Polos
# 4920   https://m.media-amazon.com/images/I/61qj+dkW4U...  T-shirts & Polos
# 18275  https://m.media-amazon.com/images/W/IMAGERENDE...  T-shirts & Polos
# 162    https://m.media-amazon.com/images/I/61XzgOm2z4...  T-shirts & Polos
# 8996   https://m.media-amazon.com/images/I/61YOqs0tAI...  T-shirts & Polos
# 6287   https://m.media-amazon.com/images/W/IMAGERENDE...  T-shirts & Polos
#
#       actual_price  ratings  no_of_ratings
# 18            1199      4.2           3868
# 26             799      4.0           3607
# 18025         1499      4.0              1
# 14114         1799      4.5              2
# 4613           799      4.3             10
# 4920           799      4.0             15
# 18275          799      4.4              4
# 162            999      4.2             38
# 8996           799      3.6              7
# 6287           799      3.5             10

# %%
from IPython.display import display, HTML

def display_recommendations(cart_indices, df, similarity_matrix, top_n=5):
    recommendations = recommend(cart_indices, df, similarity_matrix, top_n)
    
    html = "<h3>Productos Recomendados</h3><table>"
    for _, row in recommendations.iterrows():
        html += f"""
        <tr>
            <td><img src="{row['image']}" width="100"></td>
            <td><b>{row['name']}</b><br>
                Categoría: {row['main_category']}<br>
                Subcategoría: {row['sub_category']}<br>
                Precio: {row['actual_price']}<br>
                Calificación: {row['ratings']} ({row['no_of_ratings']} valoraciones)
            </td>
        </tr>
        """
    html += "</table>"
    
    display(HTML(html))

# Llamada a la función
display_recommendations(cart_indices, df, similarity_matrix, top_n=10)
# Out:
# <h3>Productos Recomendados</h3><table>
#         <tr>
#             <td><img src="https://m.media-amazon.com/images/I/81RcNGzlIhL._AC_UL320_.jpg" width="100"></td>
#             <td><b>Allen Solly Men's Regular Fit Polo</b><br>
#                 Categoría: men's clothing<br>
#                 Subcategoría: T-shirts & Polos<br>
#                 Precio: 1199<br>
#                 Calificación: 4.2 (3868 valoraciones)
#             </td>
#         </tr>
#
#         <tr>
#             <td><img src="https://m.media-amazon.com/images/I/71m0PW9bIML._AC_UL320_.jpg" width="100"></td>
#             <td><b>Allen Solly Men's Regular Fit T-Shirt</b><br>
#                 Categoría: men's clothing<br>
#                 Subcategoría: T-shirts & Polos<br>
#                 Precio: 799<br>
#                 Calificación: 4.0 (3607 valoraciones)
#             </td>
#         </tr>
#
#         <tr>
#             <td><img src="https://m.media-amazon.com/images/I/51LmPsR0XZL._AC_UL320_.jpg" width="100"></td>
#             <td><b>Allen Solly Men's Regular Fit Polo Shirt</b><br>
#                 Categoría: men's clothing<br>
#                 Subcategoría: T-shirts & Polos<br>
#                 Precio: 1499<br>
#                 Calificación: 4.0 (1 valoraciones)
#             </td>
#         </tr>
#
#         <tr>
#             <td><img src="https://m.media-amazon.com/images/I/519jb9GGiQL._AC_UL320_.jpg" width="100"></td>
#             <td><b>Allen Solly Men's Regular Polo Shirt</b><br>
#                 Categoría: men's clothing<br>
#                 Subcategoría: T-shirts & Polos<br>
#                 Precio: 1799<br>
#                 Calificación: 4.5 (2 valoraciones)
#             </td>
#         </tr>
#
#         <tr>
#             <td><img src="https://m.media-amazon.com/images/I/61KrpVDw9iL._AC_UL320_.jpg" width="100"></td>
#             <td><b>Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFC84398_Navy_Medium)</b><br>
#                 Categoría: men's clothing<br>
#                 Subcategoría: T-shirts & Polos<br>
#                 Precio: 799<br>
#                 Calificación: 4.3 (10 valoraciones)
#             </td>
#         </tr>
#
#         <tr>
#             <td><img src="https://m.media-amazon.com/images/I/61qj+dkW4UL._AC_UL320_.jpg" width="100"></td>
#             <td><b>Allen Solly Men's Regular Fit T-Shirt (ALKCVSGF195222_Peach_Medium)</b><br>
#                 Categoría: men's clothing<br>
#                 Subcategoría: T-shirts & Polos<br>
#                 Precio: 799<br>
#                 Calificación: 4.0 (15 valoraciones)
#             </td>
#         </tr>
#
#         <tr>
#             <td><img src="https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/61YOqs0tAIL._AC_UL320_.jpg" width="100"></td>
#             <td><b>Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFE60941_Yellow Ochre_Small)</b><br>
#                 Categoría: men's clothing<br>
#                 Subcategoría: T-shirts & Polos<br>
#                 Precio: 799<br>
#                 Calificación: 4.4 (4 valoraciones)
#             </td>
#         </tr>
#
#         <tr>
#             <td><img src="https://m.media-amazon.com/images/I/61XzgOm2z4L._AC_UL320_.jpg" width="100"></td>
#             <td><b>Allen Solly Men Polo</b><br>
#                 Categoría: men's clothing<br>
#                 Subcategoría: T-shirts & Polos<br>
#                 Precio: 999<br>
#                 Calificación: 4.2 (38 valoraciones)
#             </td>
#         </tr>
#
#         <tr>
#             <td><img src="https://m.media-amazon.com/images/I/61YOqs0tAIL._AC_UL320_.jpg" width="100"></td>
#             <td><b>Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFE60941_Yellow Ochre_Extra Large)</b><br>
#                 Categoría: men's clothing<br>
#                 Subcategoría: T-shirts & Polos<br>
#                 Precio: 799<br>
#                 Calificación: 3.6 (7 valoraciones)
#             </td>
#         </tr>
#
#         <tr>
#             <td><img src="https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T2/images/I/61KrpVDw9iL._AC_UL320_.jpg" width="100"></td>
#             <td><b>Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFC84398_Navy_Extra Large)</b><br>
#                 Categoría: men's clothing<br>
#                 Subcategoría: T-shirts & Polos<br>
#                 Precio: 799<br>
#                 Calificación: 3.5 (10 valoraciones)
#             </td>
#         </tr>
#         </table>

# %% [markdown]
# <p align="center"><strong>Figura 1:</strong> Productos Recomendados.</p>
#
# <p align="center"><em style="font-size: smaller;">Elaboración propia.</em></p>

# %%
print(similarity_matrix.shape)
# Out:
# (12092, 12092)

# %% [markdown]
# ## Matriz de Similitud entre Productos

# %%
similarity_matrix = similarity_matrix.toarray()

similarity_df = pd.DataFrame(similarity_matrix, index=df['name'], columns=df['name'])
print(similarity_df)
# Out:
# name                                                Allen Solly Men's Regular Fit Polo  \
# name
# Allen Solly Men's Regular Fit Polo                                            1.000000
# Van Heusen Men's Regular Fit Polo Shirt                                       0.806340
# Scott International Men's Regular Fit T-Shirt (...                            0.828774
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                            0.724706
# Amazon Brand - Symbol Men's Regular Polo Shirt                                0.781704
# ...                                                                                ...
# Puma Men's Polyester Sweatshirt                                               0.730426
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                            0.750562
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                            0.768351
# Workshop Graphic Printed T-Shirt for Men & Wome...                            0.709655
# STAND OUT Men's & Women's Regular Fit T-Shirt                                 0.760314
#
# name                                                Van Heusen Men's Regular Fit Polo Shirt  \
# name
# Allen Solly Men's Regular Fit Polo                                                 0.806340
# Van Heusen Men's Regular Fit Polo Shirt                                            1.000000
# Scott International Men's Regular Fit T-Shirt (...                                 0.832228
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                 0.812751
# Amazon Brand - Symbol Men's Regular Polo Shirt                                     0.814521
# ...                                                                                     ...
# Puma Men's Polyester Sweatshirt                                                    0.803928
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                 0.831238
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                 0.845612
# Workshop Graphic Printed T-Shirt for Men & Wome...                                 0.788200
# STAND OUT Men's & Women's Regular Fit T-Shirt                                      0.841066
#
# name                                                Scott International Men's Regular Fit T-Shirt (Pack of 3)  \
# name
# Allen Solly Men's Regular Fit Polo                                                           0.828774
# Van Heusen Men's Regular Fit Polo Shirt                                                      0.832228
# Scott International Men's Regular Fit T-Shirt (...                                           1.000000
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                           0.836597
# Amazon Brand - Symbol Men's Regular Polo Shirt                                               0.818143
# ...                                                                                               ...
# Puma Men's Polyester Sweatshirt                                                              0.813545
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                           0.828343
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                           0.855793
# Workshop Graphic Printed T-Shirt for Men & Wome...                                           0.805777
# STAND OUT Men's & Women's Regular Fit T-Shirt                                                0.851106
#
# name                                                TOPLOT T-Shirt for Men||T Shirt||White T-Shirt for Men||T-Shirt for Boys||Regular Fit T-Shirt for Mens||T Shirt for Men||t...  \
# name
# Allen Solly Men's Regular Fit Polo                                                           0.724706
# Van Heusen Men's Regular Fit Polo Shirt                                                      0.812751
# Scott International Men's Regular Fit T-Shirt (...                                           0.836597
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                           1.000000
# Amazon Brand - Symbol Men's Regular Polo Shirt                                               0.817969
# ...                                                                                               ...
# Puma Men's Polyester Sweatshirt                                                              0.878877
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                           0.903964
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                           0.894053
# Workshop Graphic Printed T-Shirt for Men & Wome...                                           0.885764
# STAND OUT Men's & Women's Regular Fit T-Shirt                                                0.919600
#
# name                                                Amazon Brand - Symbol Men's Regular Polo Shirt  \
# name
# Allen Solly Men's Regular Fit Polo                                                        0.781704
# Van Heusen Men's Regular Fit Polo Shirt                                                   0.814521
# Scott International Men's Regular Fit T-Shirt (...                                        0.818143
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                        0.817969
# Amazon Brand - Symbol Men's Regular Polo Shirt                                            1.000000
# ...                                                                                            ...
# Puma Men's Polyester Sweatshirt                                                           0.820442
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                        0.835592
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                        0.852968
# Workshop Graphic Printed T-Shirt for Men & Wome...                                        0.804717
# STAND OUT Men's & Women's Regular Fit T-Shirt                                             0.843894
#
# name                                                LEOTUDE Women's Cottonblend Half Sleeve Oversized T-Shirts (Color: Orange)  \
# name
# Allen Solly Men's Regular Fit Polo                                                           0.723374
# Van Heusen Men's Regular Fit Polo Shirt                                                      0.794038
# Scott International Men's Regular Fit T-Shirt (...                                           0.794140
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                           0.847256
# Amazon Brand - Symbol Men's Regular Polo Shirt                                               0.812943
# ...                                                                                               ...
# Puma Men's Polyester Sweatshirt                                                              0.898656
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                           0.907170
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                           0.909790
# Workshop Graphic Printed T-Shirt for Men & Wome...                                           0.897189
# STAND OUT Men's & Women's Regular Fit T-Shirt                                                0.925945
#
# name                                                Chromozome Men Mens Tshirts  \
# name
# Allen Solly Men's Regular Fit Polo                                     0.771052
# Van Heusen Men's Regular Fit Polo Shirt                                0.812170
# Scott International Men's Regular Fit T-Shirt (...                     0.821680
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                     0.892714
# Amazon Brand - Symbol Men's Regular Polo Shirt                         0.820977
# ...                                                                         ...
# Puma Men's Polyester Sweatshirt                                        0.866401
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                     0.881291
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                     0.890545
# Workshop Graphic Printed T-Shirt for Men & Wome...                     0.846544
# STAND OUT Men's & Women's Regular Fit T-Shirt                          0.881092
#
# name                                                London Hills Solid Men Half Sleeve Pure Cotton Round Neck T-Shirt  \
# name
# Allen Solly Men's Regular Fit Polo                                                           0.725954
# Van Heusen Men's Regular Fit Polo Shirt                                                      0.798687
# Scott International Men's Regular Fit T-Shirt (...                                           0.821263
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                           0.872920
# Amazon Brand - Symbol Men's Regular Polo Shirt                                               0.815580
# ...                                                                                               ...
# Puma Men's Polyester Sweatshirt                                                              0.891514
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                           0.905549
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                           0.911397
# Workshop Graphic Printed T-Shirt for Men & Wome...                                           0.893698
# STAND OUT Men's & Women's Regular Fit T-Shirt                                                0.904105
#
# name                                                Amazon Brand - Symbol Men's Regular Fit T-Shirt  \
# name
# Allen Solly Men's Regular Fit Polo                                                         0.710722
# Van Heusen Men's Regular Fit Polo Shirt                                                    0.778734
# Scott International Men's Regular Fit T-Shirt (...                                         0.782914
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                         0.845318
# Amazon Brand - Symbol Men's Regular Polo Shirt                                             0.974381
# ...                                                                                             ...
# Puma Men's Polyester Sweatshirt                                                            0.831166
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                         0.859044
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                         0.861142
# Workshop Graphic Printed T-Shirt for Men & Wome...                                         0.818695
# STAND OUT Men's & Women's Regular Fit T-Shirt                                              0.870890
#
# name                                                Adidas Men's Regular Polo Shirt  \
# name
# Allen Solly Men's Regular Fit Polo                                         0.722813
# Van Heusen Men's Regular Fit Polo Shirt                                    0.800612
# Scott International Men's Regular Fit T-Shirt (...                         0.786517
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                         0.846334
# Amazon Brand - Symbol Men's Regular Polo Shirt                             0.807485
# ...                                                                             ...
# Puma Men's Polyester Sweatshirt                                            0.837477
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                         0.853130
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                         0.871381
# Workshop Graphic Printed T-Shirt for Men & Wome...                         0.818704
# STAND OUT Men's & Women's Regular Fit T-Shirt                              0.869769
#
# name                                                ...  \
# name                                                ...
# Allen Solly Men's Regular Fit Polo                  ...
# Van Heusen Men's Regular Fit Polo Shirt             ...
# Scott International Men's Regular Fit T-Shirt (...  ...
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...  ...
# Amazon Brand - Symbol Men's Regular Polo Shirt      ...
# ...                                                 ...
# Puma Men's Polyester Sweatshirt                     ...
# Ruggers Men's Striped Slim fit T-Shirt (2815316...  ...
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...  ...
# Workshop Graphic Printed T-Shirt for Men & Wome...  ...
# STAND OUT Men's & Women's Regular Fit T-Shirt       ...
#
# name                                                Puma Men's Regular Fit T-Shirt  \
# name
# Allen Solly Men's Regular Fit Polo                                        0.712895
# Van Heusen Men's Regular Fit Polo Shirt                                   0.789675
# Scott International Men's Regular Fit T-Shirt (...                        0.799098
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                        0.878044
# Amazon Brand - Symbol Men's Regular Polo Shirt                            0.787332
# ...                                                                            ...
# Puma Men's Polyester Sweatshirt                                           0.950006
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                        0.864376
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                        0.866460
# Workshop Graphic Printed T-Shirt for Men & Wome...                        0.827182
# STAND OUT Men's & Women's Regular Fit T-Shirt                             0.896035
#
# name                                                Spykar Men's Cotton Slim Fit Half Sleeves Polo Collar T-Shirts (Mkt-01bj-089)  \
# name
# Allen Solly Men's Regular Fit Polo                                                           0.719678
# Van Heusen Men's Regular Fit Polo Shirt                                                      0.790416
# Scott International Men's Regular Fit T-Shirt (...                                           0.797354
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                           0.837332
# Amazon Brand - Symbol Men's Regular Polo Shirt                                               0.795393
# ...                                                                                               ...
# Puma Men's Polyester Sweatshirt                                                              0.857168
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                           0.937278
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                           0.939349
# Workshop Graphic Printed T-Shirt for Men & Wome...                                           0.846136
# STAND OUT Men's & Women's Regular Fit T-Shirt                                                0.872589
#
# name                                                TECIDO Men's Lycra Slim Fit T-Shirt | Round Neck Half Sleeves, Large Navy Blue  \
# name
# Allen Solly Men's Regular Fit Polo                                                           0.728573
# Van Heusen Men's Regular Fit Polo Shirt                                                      0.797364
# Scott International Men's Regular Fit T-Shirt (...                                           0.803999
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                           0.874544
# Amazon Brand - Symbol Men's Regular Polo Shirt                                               0.806581
# ...                                                                                               ...
# Puma Men's Polyester Sweatshirt                                                              0.895050
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                           0.925533
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                           0.937547
# Workshop Graphic Printed T-Shirt for Men & Wome...                                           0.880470
# STAND OUT Men's & Women's Regular Fit T-Shirt                                                0.899550
#
# name                                                Prink King in The North T-Shirt Black | Game of Thrones Printed Tshirt | Printed Tees | Black Tshirts for Men |  \
# name
# Allen Solly Men's Regular Fit Polo                                                           0.727532
# Van Heusen Men's Regular Fit Polo Shirt                                                      0.798983
# Scott International Men's Regular Fit T-Shirt (...                                           0.795585
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                           0.859488
# Amazon Brand - Symbol Men's Regular Polo Shirt                                               0.816981
# ...                                                                                               ...
# Puma Men's Polyester Sweatshirt                                                              0.907438
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                           0.901735
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                           0.917295
# Workshop Graphic Printed T-Shirt for Men & Wome...                                           0.910175
# STAND OUT Men's & Women's Regular Fit T-Shirt                                                0.904352
#
# name                                                Quote Marshals Men's Regular Fit T-Shirt  \
# name
# Allen Solly Men's Regular Fit Polo                                                  0.762284
# Van Heusen Men's Regular Fit Polo Shirt                                             0.844106
# Scott International Men's Regular Fit T-Shirt (...                                  0.866481
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                  0.928632
# Amazon Brand - Symbol Men's Regular Polo Shirt                                      0.847238
# ...                                                                                      ...
# Puma Men's Polyester Sweatshirt                                                     0.908181
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                  0.933781
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                  0.937737
# Workshop Graphic Printed T-Shirt for Men & Wome...                                  0.940303
# STAND OUT Men's & Women's Regular Fit T-Shirt                                       0.963106
#
# name                                                Puma Men's Polyester Sweatshirt  \
# name
# Allen Solly Men's Regular Fit Polo                                         0.730426
# Van Heusen Men's Regular Fit Polo Shirt                                    0.803928
# Scott International Men's Regular Fit T-Shirt (...                         0.813545
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                         0.878877
# Amazon Brand - Symbol Men's Regular Polo Shirt                             0.820442
# ...                                                                             ...
# Puma Men's Polyester Sweatshirt                                            1.000000
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                         0.907728
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                         0.922568
# Workshop Graphic Printed T-Shirt for Men & Wome...                         0.878124
# STAND OUT Men's & Women's Regular Fit T-Shirt                              0.910998
#
# name                                                Ruggers Men's Striped Slim fit T-Shirt (281531624_LT-GR-Mel_S_HS  \
# name
# Allen Solly Men's Regular Fit Polo                                                           0.750562
# Van Heusen Men's Regular Fit Polo Shirt                                                      0.831238
# Scott International Men's Regular Fit T-Shirt (...                                           0.828343
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                           0.903964
# Amazon Brand - Symbol Men's Regular Polo Shirt                                               0.835592
# ...                                                                                               ...
# Puma Men's Polyester Sweatshirt                                                              0.907728
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                           1.000000
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                           0.970662
# Workshop Graphic Printed T-Shirt for Men & Wome...                                           0.889061
# STAND OUT Men's & Women's Regular Fit T-Shirt                                                0.938574
#
# name                                                Indian Terrain Men's Plain Slim Fit Polo (ITMTS00666RedSS_Red_S)  \
# name
# Allen Solly Men's Regular Fit Polo                                                           0.768351
# Van Heusen Men's Regular Fit Polo Shirt                                                      0.845612
# Scott International Men's Regular Fit T-Shirt (...                                           0.855793
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                           0.894053
# Amazon Brand - Symbol Men's Regular Polo Shirt                                               0.852968
# ...                                                                                               ...
# Puma Men's Polyester Sweatshirt                                                              0.922568
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                           0.970662
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                           1.000000
# Workshop Graphic Printed T-Shirt for Men & Wome...                                           0.894740
# STAND OUT Men's & Women's Regular Fit T-Shirt                                                0.933309
#
# name                                                Workshop Graphic Printed T-Shirt for Men & Women | Funny Quote Cotton T-Shirt |Main UDEGA AAJ TEE| Sarcasam T-Shirt | Half...  \
# name
# Allen Solly Men's Regular Fit Polo                                                           0.709655
# Van Heusen Men's Regular Fit Polo Shirt                                                      0.788200
# Scott International Men's Regular Fit T-Shirt (...                                           0.805777
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                           0.885764
# Amazon Brand - Symbol Men's Regular Polo Shirt                                               0.804717
# ...                                                                                               ...
# Puma Men's Polyester Sweatshirt                                                              0.878124
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                           0.889061
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                           0.894740
# Workshop Graphic Printed T-Shirt for Men & Wome...                                           1.000000
# STAND OUT Men's & Women's Regular Fit T-Shirt                                                0.930952
#
# name                                                STAND OUT Men's & Women's Regular Fit T-Shirt
# name
# Allen Solly Men's Regular Fit Polo                                                       0.760314
# Van Heusen Men's Regular Fit Polo Shirt                                                  0.841066
# Scott International Men's Regular Fit T-Shirt (...                                       0.851106
# TOPLOT T-Shirt for Men||T Shirt||White T-Shirt ...                                       0.919600
# Amazon Brand - Symbol Men's Regular Polo Shirt                                           0.843894
# ...                                                                                           ...
# Puma Men's Polyester Sweatshirt                                                          0.910998
# Ruggers Men's Striped Slim fit T-Shirt (2815316...                                       0.938574
# Indian Terrain Men's Plain Slim Fit Polo (ITMTS...                                       0.933309
# Workshop Graphic Printed T-Shirt for Men & Wome...                                       0.930952
# STAND OUT Men's & Women's Regular Fit T-Shirt                                            1.000000
#
# [12092 rows x 12092 columns]

# %% [markdown]
# <p align="center"><strong>Tabla 3:</strong> Matriz de similitud entre Productos.</p>
#
# <p align="center"><em style="font-size: smaller;">Elaboración propia.</em></p>

# %% [markdown]
# ### Evaluación

# %% [markdown]
# Para evaluar el rendimiento del sistema se usan las siguientes métricas:
#
# - **Precisión**: Fracción de recomendaciones relevantes sobre el total de recomendaciones realizadas.
# - **Recall**: Fracción de productos relevantes correctamente recomendados.
# - **F1-score**: Media armónica entre precisión y recall.
#
# Resultados obtenidos:
#
# $$
# \begin{equation}
# \text{Precision} = \frac{TP}{TP + FP}
# \end{equation}
# $$
#
# $$
# \begin{equation}
# \text{Recall} = \frac{TP}{TP + FN}
# \end{equation}
# $$
#
# $$
# \begin{equation}
# F1 = 2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}
# \end{equation}
# $$
#
# Donde **TP** son los productos relevantes recomendados, **FP** son las recomendaciones incorrectas y **FN** son los productos relevantes no recomendados.
#
# Con los resultados obtenidos:
#
# - **Precisión = 0.60**: Indica que el 60% de los productos recomendados fueron realmente relevantes para el usuario.
# - **Recall = 1.00**: Demuestra que se lograron recuperar todos los productos relevantes del conjunto de datos.
# - **F1-score = 0.75**: Representa el balance entre precisión y recall, con un buen desempeño general.
#
# El alto valor de **recall** muestra que el sistema es efectivo en identificar productos relevantes, asegurando que los usuarios vean todas las opciones adecuadas.

# %%
# Supongamos que estos son los productos relevantes para el usuario (ground truth)
relevant_items = {"Allen Solly Men's Regular Fit Polo", "Allen Solly Men's Regular Fit Polo Shirt", "Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFC84398_Navy_Medium)"}

# Y estos son los productos que el sistema recomendó
recommended_items = {"Adidas Men T-Shirt", "Allen Solly Men's Snug Fit T-Shirt", "Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFE60941_Yellow Ochre_Extra Large)", "Allen Solly Men's Regular Fit Polo", "Allen Solly Men's Regular Fit T-Shirt", "Allen Solly Men's Regular Fit Polo Shirt",  "Allen Solly Men Polo"}

def precision_recall_f1(relevant_items, recommended_items):
    # Intersección entre relevantes y recomendados
    true_positives = len(relevant_items.intersection(recommended_items))
    
    # Precision: cuántos recomendados son realmente relevantes
    precision = true_positives / len(recommended_items) if recommended_items else 0
    
    # Recall: cuántos relevantes fueron recomendados
    recall = true_positives / len(relevant_items) if relevant_items else 0
    
    # F1-score: balance entre precisión y recall
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) else 0

    return precision, recall, f1

recommended_df = recommend(cart_indices, df, similarity_matrix, top_n=5)

# Convertir los nombres de los productos recomendados en un conjunto
recommended_items = set(recommended_df['name'])  

# Evaluación de precisión y recall
precision, recall, f1 = precision_recall_f1(relevant_items, recommended_items)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")
# Out:
# Precision: 0.60
# Recall: 1.00
# F1-score: 0.75

# %%
def get_top_similarities(similarity_df, product_name, top_n=10):
    # Verifica que el producto exista en el DataFrame
    if product_name not in similarity_df.index:
        print("Producto no encontrado")
        return None
    
    # Obtener la fila correspondiente al producto
    sim_data = similarity_df.loc[product_name]
    
    # Si sim_data es un DataFrame (por índices duplicados), tomar la primera fila
    if isinstance(sim_data, pd.DataFrame):
        sim_series = sim_data.iloc[0]
    else:
        sim_series = sim_data
    
    # Ordenar la Serie de forma descendente
    sorted_sim = sim_series.sort_values(ascending=False)
    
    # Excluir el propio producto (donde la similitud es 1.0)
    sorted_sim = sorted_sim[sorted_sim.index != product_name]
    
    # Devolver los top_n valores
    return sorted_sim.head(top_n)

# Ejemplo de uso:
product_name = "Allen Solly Men's Regular Fit Polo"
top_similarities = get_top_similarities(similarity_df, product_name, top_n=60)
print(top_similarities)
# Out:
# name
# Allen Solly Men's Regular Fit T-Shirt                                              0.889098
# Allen Solly Men's Regular Fit Polo Shirt                                           0.885141
# Allen Solly Men's Regular Fit Polo Shirt                                           0.885112
# Allen Solly Men's Regular Fit Polo Shirt                                           0.885067
# Allen Solly Men's Regular Fit Polo Shirt                                           0.884802
# Allen Solly Men's Regular Fit Polo Shirt                                           0.884726
# Allen Solly Men's Regular Fit Polo Shirt                                           0.884726
# Allen Solly Men's Regular Fit Polo Shirt                                           0.884726
# Allen Solly Men's Regular Fit Polo Shirt                                           0.884539
# Allen Solly Men's Regular Fit Polo Shirt                                           0.884539
# Allen Solly Men's Regular Fit Polo Shirt                                           0.884390
# Allen Solly Men's Regular Fit Polo Shirt                                           0.884317
# Allen Solly Men's Regular Fit Polo Shirt                                           0.883860
# Allen Solly Men's Regular Fit Polo Shirt                                           0.883647
# Allen Solly Men's Regular Fit Polo Shirt                                           0.883647
# Allen Solly Men's Regular Fit Polo Shirt                                           0.882374
# Allen Solly Men's Regular Fit Polo Shirt                                           0.882362
# Allen Solly Men's Regular Fit Polo Shirt                                           0.882221
# Allen Solly Men's Regular Fit Polo Shirt                                           0.882221
# Allen Solly Men's Regular Fit Polo Shirt                                           0.881660
# Allen Solly Men's Regular Fit Polo Shirt                                           0.881660
# Allen Solly Men's Regular Fit Polo Shirt                                           0.881475
# Allen Solly Men's Regular Polo Shirt                                               0.881227
# Allen Solly Men's Regular Fit Polo Shirt                                           0.879874
# Allen Solly Men's Regular Polo Shirt                                               0.878991
# Allen Solly Men's Regular Fit T-Shirt                                              0.876153
# Allen Solly Men's Regular Fit T-Shirt                                              0.875679
# Allen Solly Men's Regular Fit T-Shirt                                              0.875679
# Allen Solly Men's Regular Fit T-Shirt                                              0.875603
# Allen Solly Men's Regular Fit T-Shirt                                              0.875591
# Allen Solly Men's Regular Fit T-Shirt                                              0.875131
# Allen Solly Men's Regular Fit T-Shirt                                              0.875131
# Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFC84398_Navy_Medium)                 0.875034
# Allen Solly Men's Regular Fit T-Shirt (ALKCVSGF195222_Peach_Medium)                0.875015
# Allen Solly Men's Regular Fit T-Shirt                                              0.874912
# Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFE60941_Yellow Ochre_Small)          0.874871
# Allen Solly Men Polo                                                               0.874347
# Allen Solly Men's Regular Fit T-Shirt                                              0.873703
# Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFE60941_Yellow Ochre_Extra Large)    0.873571
# Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFE60941_Yellow Ochre_Extra Large)    0.873571
# Allen Solly Men Polo                                                               0.873424
# Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFC84398_Navy_Extra Large)            0.873210
# Allen Solly Men's Regular Fit T-Shirt (ALKCVSGFC84398_Navy_Extra Large)            0.873210
# Allen Solly Men Polo Shirt                                                         0.872640
# Allen Solly Men Polo Shirt                                                         0.872624
# Allen Solly Men Polo Shirt                                                         0.872624
# Allen Solly Men's Regular Fit T-Shirt                                              0.872051
# Allen Solly Men's Snug Fit T-Shirt                                                 0.870756
# Allen Solly Men's Snug Fit T-Shirt                                                 0.870632
# Allen Solly Men's Snug Fit T-Shirt                                                 0.870632
# Allen Solly Men Polo Shirt                                                         0.870502
# Allen Solly Men Polo Shirt                                                         0.870429
# Allen Solly Men's Snug Fit T-Shirt (ALKCVSGFY61905_Pink Large)                     0.869295
# Allen Solly Men Polo Shirt                                                         0.869146
# Allen Solly Men's Regular Fit T Shirt                                              0.868586
# Allen Solly Men's Snug Fit T-Shirt (ALKCVSGFH35502_Yellow Medium)                  0.868073
# Allen Solly Men's Snug Fit T-Shirt                                                 0.864841
# Allen Solly Men's Snug Fit T-Shirt (ALKCVSGFY89177_Olive Extra Large)              0.863269
# Allen Solly Men T-Shirt                                                            0.863243
# Allen Solly Men's Regular Fit T-Shirt                                              0.862405
# Name: Allen Solly Men's Regular Fit Polo, dtype: float64

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# - El sistema de recomendación basado en similitud de contenido es capaz de generar sugerencias relevantes para los usuarios, aprovechando características textuales y numéricas de los productos. Su buen desempeño en recall garantiza que los productos adecuados sean considerados, mejorando la experiencia de búsqueda y exploración en plataformas de comercio electrónico.
#
# - Al trabajar con matrices diversas, hay que tener en cuenta la dimensionalidad y la eficiencia computacional. La representación dispersa de matrices, como en el caso de TF-IDF o embeddings de productos, puede ser útil para reducir el consumo de memoria y acelerar cálculos de similitud. Es fundamental elegir técnicas de reducción de dimensionalidad adecuadas, como Truncated SVD o PCA, para evitar la pérdida de información clave y mejorar el rendimiento del modelo sin comprometer la precisión de las recomendaciones.

# %% [markdown]
# ## Referencias

# %% [markdown]
# Scikit-learn. (s.f.). Cosine similarity. Recuperado el 18 de febrero de 2025, de https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html
#
# GeeksforGeeks. (s.f.). Cosine similarity. Recuperado el 18 de febrero de 2025, de https://www.geeksforgeeks.org/cosine-similarity/
#
# Scikit-learn. (s.f.). Precision score. Recuperado el 18 de febrero de 2025, de https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html
#
# GeeksforGeeks. (s.f.). Understanding TF-IDF (Term Frequency - Inverse Document Frequency). Recuperado el 18 de febrero de 2025, de https://www.geeksforgeeks.org/understanding-tf-idf-term-frequency-inverse-document-frequency/
#
# Scikit-learn. (s.f.). Truncated SVD. Recuperado el 18 de febrero de 2025, de https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4ce25df3-b939-4195-8b6c-572825e9af1f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
